# %% [markdown]
# ---
# title: "hello world"
# description: 'The first post on this blog'
# author: "janf"
# date: "2023-06-30"
# date-format: iso
# image: welcome_thumbnail.jpg
# categories: [social]
# toc: true
# ---

# %% [markdown]
# This is the first post on this blog. Seavas!
#
# Hello, I'm [Jan F.](../../about.qmd) from west austria 🇦🇹 . <br> I like to learn or create new things. Here i take notes about these processes or outcomes ✌️

# %% [markdown]
# <br>
#
# ---
# ![flora - janf - 2020](welcome_thumbnail.jpg){fig-align="left" width=100%}
